# %%
import pandas as pd
import json

# %%
with open('indexes.sav', 'r') as f:
    indexes = json.loads(f.read())
indexes
# Out:
# {"('our',)": 0,
#  "('are',)": 1,
#  "('the',)": 2,
#  "('reason',)": 3,
#  "('of',)": 4,
#  "('this',)": 5,
#  "('may',)": 6,
#  "('allah',)": 7,
#  "('us',)": 8,
#  "('all',)": 9,
#  "('are', 'the')": 10,
#  "('of', 'this')": 11,
#  "('may', 'allah')": 12,
#  "('us', 'all')": 13,
#  "('forest',)": 14,
#  "('fire',)": 15,
#  "('near',)": 16,
#  "('la',)": 17,
#  "('canada',)": 18,
#  "('forest', 'fire')": 19,
#  "('fire', 'near')": 20,
#  "('residents',)": 21,
#  "('asked',)": 22,
#  "('to',)": 23,
#  "('shelter',)": 24,
#  "('in',)": 25,
#  "('place',)": 26,
#  "('being',)": 27,
#  "('by',)": 28,
#  "('officers',)": 29,
#  "('no',)": 30,
#  "('other',)": 31,
#  "('evacuation',)": 32,
#  "('or',)": 33,
#  "('orders',)": 34,
#  "('expected',)": 35,
#  "('shelter', 'in')": 36,
#  "('in', 'place')": 37,
#  "('are', 'being')": 38,
#  "('people',)": 39,
#  "('california',)": 40,
#  "('in', 'california')": 41,
#  "('just',)": 42,
#  "('got',)": 43,
#  "('sent',)": 44,
# ...
